# %%
import pandas as pd
from sodapy import Socrata
import numpy as np
import matplotlib as mlt
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
client = Socrata("data.cityofnewyork.us", None)
result = client.get("mh6y-g6wt", limit=5000)
results_df = pd.DataFrame.from_records(result)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
#There are a few different cohort categroies. To standardize the dataset, we only use the "4 Year June" cohort of each year
std_cohort = results_df[results_df['cohort_category']=='4 Year  June']
#We only need the information for black student
std_cohort = std_cohort[results_df['demographic']=='Black']
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %%
std_cohort['total_grads_pct_of_cohort'] = std_cohort['total_grads_pct_of_cohort'].str.rstrip('%').astype('float') / 100

# %%
std_cohort['total_grads_num']= std_cohort['total_grads_num'].str.replace(',','').astype('int')

# %%
borough = ['Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island']
color =['blue','black','yellow','green','grey']

# %%
bronx = std_cohort[std_cohort['borough'] == 'Bronx']

# %%
borough_df
# Out:
#     advanced_regents_num advanced_regents_pct_of_cohort  \
# 374                   39                          6.30%
# 377                   39                          5.70%
# 380                   59                          8.00%
# 383                   78                         11.20%
# 386                   62                          8.00%
# 390                   85                         11.00%
# 394                   55                          6.70%
#
#     advanced_regents_pct_of_grads        borough cohort_category cohort_year  \
# 374                        13.80%  Staten Island    4 Year  June        2001
# 377                        11.70%  Staten Island    4 Year  June        2002
# 380                        14.90%  Staten Island    4 Year  June        2003
# 383                        22.30%  Staten Island    4 Year  June        2004
# 386                        14.50%  Staten Island    4 Year  June        2005
# 390                        19.90%  Staten Island    4 Year  June        2006
# 394                        11.70%  Staten Island    4 Year  June        2007
#
#     demographic dropped_out_num dropped_out_pct_of_cohort local_num  \
# 374       Black             100                    16.10%       122
# 377       Black              90                    13.10%       132
# 380       Black              72                     9.70%       136
# 383       Black              90                    13.00%       102
# 386       Black              87                    11.20%       140
# 390       Black             104                    13.50%        94
# 394       Black              96                    11.80%        75
#
#                 ...             regents_w_o_advanced_pct_of_cohort  \
# 374             ...                                         19.60%
# 377             ...                                         23.90%
# 380             ...                                         27.20%
# 383             ...                                         24.40%
# 386             ...                                         29.20%
# 390             ...                                         32.20%
# 394             ...                                         41.50%
#
#     regents_w_o_advanced_pct_of_grads still_enrolled_num  \
# 374                            43.30%                207
# 377                            49.10%                225
# 380                            50.80%                239
# 383                            48.40%                231
# 386                            52.90%                196
# 390                            58.10%                195
# 394                            72.30%                215
#
#     still_enrolled_pct_of_cohort total_cohort_num total_grads_num  \
# 374                       33.30%              621             282
# 377                       32.80%              686             334
# 380                       32.30%              739             396
# 383                       33.30%              694             349
# 386                       25.20%              778             429
# 390                       25.30%              771             427
# 394                       26.30%              817             469
#
#     total_grads_pct_of_cohort total_regents_num  total_regents_pct_of_cohort  \
# 374                     0.454               161                       25.90%
# 377                     0.487               203                       29.60%
# 380                     0.536               260                       35.20%
# 383                     0.503               247                       35.60%
# 386                     0.551               289                       37.10%
# 390                     0.554               333                       43.20%
# 394                     0.574               394                       48.20%
#
#      total_regents_pct_of_grads
# 374                      57.10%
# 377                      60.80%
# 380                      65.70%
# 383                      70.80%
# 386                      67.40%
# 390                      78.00%
# 394                      84.00%
#
# [7 rows x 23 columns]

# %%
fig, axs = plt.subplots(1,2,figsize = (16,8))

colors = ['Pink', 'Grey', 'Tan', 'Green','Salmon']

for num in range(5):
    b = borough[num]
    c = color[num]
    borough_df = std_cohort[std_cohort['borough'] == b]
    
    
    axs[0].plot(borough_df.cohort_year, borough_df.total_grads_num, alpha=1,lw=3,color = colors[num])
    
    axs[1].plot(borough_df.cohort_year, borough_df.total_grads_pct_of_cohort, alpha=1,lw=3,color = colors[num])

axs[0].set_xlabel('Cohort Year',fontsize=16)
axs[1].set_xlabel('Cohort Year',fontsize=16)
axs[0].set_ylabel('Number of Student',fontsize=16)
axs[1].set_ylabel('Graduation Rate',fontsize=16)

axs[0].set_title('Number of Black Graduating Student in Each Year in NYC',fontsize=18)
axs[1].set_title('Graduation Rate of Black Student in Each Year in NYC',fontsize=18)
axs[0].tick_params( labelsize = 14)
axs[1].tick_params( labelsize = 14)

plt.style.use('seaborn-darkgrid')
plt.legend(borough,fontsize=13)

# %% [markdown]
# #### Accroding to the review, I changed the color and the line width to make my visualization more clear.

# %% [markdown]
# Figure 1. The left subplot shows the total number of black student graduating from college each year in NYC is growing contantly form 2001 to 2006. However, in 2007, this number dropped in Bronx, Manhattan, and Brooklyn. The same situation is also refleced on the right subplot. Although the graduation rate of black student in NYC is increasly significantly from 2001 to 2006, the graduation rate in Bronx, Mahattan and Brooklyn also decreased in 2017.
